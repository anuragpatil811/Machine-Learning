# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv(r"C:\Users\Admin\Documents\Machine Learning\heart_disease_data.csv")
df.shape
# Out:
# (303, 14)

# %%
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.isna().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %%
import seaborn as sns 
sns.boxplot(data=df, y="thal")
# Out:
# <Axes: ylabel='thal'>

# %%
#Outliers = trestbps, chol, fbs, thalach, oldpeak, ca, thal

# %%
df["trestbps"].describe()
# Out:
# count    303.000000
# mean     131.623762
# std       17.538143
# min       94.000000
# 25%      120.000000
# 50%      130.000000
# 75%      140.000000
# max      200.000000
# Name: trestbps, dtype: float64

# %%
q1 = 120.0
q3 = 140.0
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["trestbps"]<ub)&(df["trestbps"]>lb)]

# %%
sns.boxplot(data=df, y="trestbps")
# Out:
# <Axes: ylabel='trestbps'>

# %%
df["chol"].describe()
# Out:
# count    290.000000
# mean     245.203448
# std       52.029237
# min      126.000000
# 25%      210.250000
# 50%      240.000000
# 75%      273.000000
# max      564.000000
# Name: chol, dtype: float64

# %%
q1 = 211.0
q3 = 273.0
IQR = q3-q1 
IQR
# Out:
# 62.0

# %%
ub = q3 + 1.5*IQR
lb = q1 - 1.5*IQR

# %%
df = df[(df["chol"]<ub)&(df["chol"]>lb)]

# %%
sns.boxplot(data=df, y="chol")
# Out:
# <Axes: >

# %%
df["thalach"].describe()
# Out:
# count    285.000000
# mean     149.477193
# std       23.294283
# min       71.000000
# 25%      132.000000
# 50%      152.000000
# 75%      168.000000
# max      202.000000
# Name: thalach, dtype: float64

# %%
q1 = 132.0
q3 = 168.0
IQR = q3 - q1

# %%
lb = q1 - 1.5*IQR 
ub = q3 + 1.5*IQR

# %%
df = df[(df["thalach"]>lb)&(df["thalach"]<ub)]

# %%
sns.boxplot(data=df, y="thalach")
# Out:
# <Axes: ylabel='thalach'>

# %%
df["oldpeak"].describe()
# Out:
# count    284.000000
# mean       0.995775
# std        1.126198
# min        0.000000
# 25%        0.000000
# 50%        0.600000
# 75%        1.600000
# max        6.200000
# Name: oldpeak, dtype: float64

# %%
q1 = 0.0
q3 = 1.6

# %%
IQR = q3 - q1 
IQR
# Out:
# 1.6

# %%
ub = q3 + 1.5*IQR
lb = q1 - 1.5*IQR

# %%
df = df[(df["oldpeak"]>lb)&(df["oldpeak"]<ub)]

# %%
sns.boxplot(data=df, y="oldpeak")
# Out:
# <Axes: ylabel='oldpeak'>

# %%
df["ca"].describe()
# Out:
# count    279.000000
# mean       0.706093
# std        1.003411
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        4.000000
# Name: ca, dtype: float64

# %%
q1 = 0.0
q3 = 1.0
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR
lb = q1 - 1.5*IQR

# %%
df = df[(df["chol"]<ub)&(df["chol"]>lb)]

# %%
sns.boxplot(data=df, y="chol")
# Out:
# <Axes: >

# %%
df["thal"].describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: thal, dtype: float64

# %%
x = df.drop("target", axis=1)
y = df["target"]

# %%
x.shape
# Out:
# (0, 13)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
#
# File c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
# ...
