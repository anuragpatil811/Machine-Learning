# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Admin\Documents\Machine Learning\Delievery Delay Prediction\Train.csv")
df.head(3)
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# 1                59           3088                    1
# 2                48           3374                    1

# %%
df.shape
# Out:
# (10999, 12)

# %%
df.isnull().sum()
# Out:
# ID                     0
# Warehouse_block        0
# Mode_of_Shipment       0
# Customer_care_calls    0
# Customer_rating        0
# Cost_of_the_Product    0
# Prior_purchases        0
# Product_importance     0
# Gender                 0
# Discount_offered       0
# Weight_in_gms          0
# Reached.on.Time_Y.N    0
# dtype: int64

# %%
df.drop(columns=["ID", "Gender"], inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns 
sns.boxplot(data=df, y="Prior_purchases")
# Out:
# <Axes: ylabel='Prior_purchases'>

# %%
df["Prior_purchases"].describe()
# Out:
# count    10999.000000
# mean         3.567597
# std          1.522860
# min          2.000000
# 25%          3.000000
# 50%          3.000000
# 75%          4.000000
# max         10.000000
# Name: Prior_purchases, dtype: float64

# %%
q1 = 3.0
q3 = 4.0
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["Prior_purchases"]>lb)&(df["Prior_purchases"]<ub)]
sns.boxplot(data=df, y="Prior_purchases")
# Out:
# <Axes: ylabel='Prior_purchases'>

# %%
sns.boxplot(data=df, y="Discount_offered")
# Out:
# <Axes: ylabel='Discount_offered'>

# %%
df["Discount_offered"].describe()
# Out:
# count    9996.000000
# mean       13.442977
# std        16.249371
# min         1.000000
# 25%         4.000000
# 50%         7.000000
# 75%        10.000000
# max        65.000000
# Name: Discount_offered, dtype: float64

# %%
q1 = 4.0
q3 = 10.0 
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["Discount_offered"]>lb)&(df["Discount_offered"]<ub)]
sns.boxplot(data=df, y="Discount_offered")
# Out:
# <Axes: ylabel='Discount_offered'>

# %%
import numpy as np 
from scipy import stats
df['z_score'] = np.abs(stats.zscore(df['Discount_offered']))
df = df[df['z_score'] < 3].copy()

# %%
df = df.drop('z_score', axis=1)
sns.boxplot(data=df, y="Discount_offered")
# Out:
# <Axes: ylabel='Discount_offered'>

# %%
sns.boxplot(data=df, y="Weight_in_gms")
# Out:
# <Axes: ylabel='Weight_in_gms'>

# %%
df.head(3)
# Out:
#   Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 3               B           Flight                    3                3
# 5               F           Flight                    3                1
# 6               D           Flight                    3                4
#
#    Cost_of_the_Product  Prior_purchases Product_importance  Discount_offered  \
# 3                  176                4             medium                10
# 5                  162                3             medium                12
# 6                  250                3                low                 3
#
#    Weight_in_gms  Reached.on.Time_Y.N
# 3           1177                    1
# 5           1417                    1
# 6           2371                    1

# %%
#For Label Encoding
df["Warehouse_block"].unique()
# Out:
# <ArrowStringArray>
# ['B', 'F', 'D', 'A', 'C']
# Length: 5, dtype: str

# %%
#Label Encoding
df["Mode_of_Shipment"].unique()
# Out:
# <ArrowStringArray>
# ['Flight', 'Ship', 'Road']
# Length: 3, dtype: str

# %%
df["Customer_rating"].unique()
# Out:
# array([3, 1, 4, 5, 2])

# %%
#For label Encoding
df["Product_importance"].unique()
# Out:
# <ArrowStringArray>
# ['medium', 'low', 'high']
# Length: 3, dtype: str

# %%
from sklearn.preprocessing import LabelEncoder 
le = LabelEncoder()

# %%
df["Mode_of_Shipment"] = le.fit_transform(df["Mode_of_Shipment"])
df["Mode_of_Shipment"].unique()
# Out:
# array([0, 2, 1])

# %%
df["Warehouse_block"] = le.fit_transform(df["Warehouse_block"])
df["Warehouse_block"].unique()
# Out:
# array([1, 4, 3, 0, 2])

# %%
df["Product_importance"] = le.fit_transform(df["Product_importance"])
df["Product_importance"].unique()
# Out:
# array([2, 1, 0])

# %%
x = df.drop("Reached.on.Time_Y.N", axis=1)
y = df["Reached.on.Time_Y.N"]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression()
log.fit(X_train, y_train)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\linear_model\_logistic.py:406: ConvergenceWarning: lbfgs failed to converge after 100 iteration(s) (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT
#
# Increase the number of iterations to improve the convergence (max_iter=100).
# You might also want to scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_predict1 = log.predict(X_test)

# %%
log.score(X_train, y_train)
# Out:
# 0.5564245810055866

# %%
from sklearn.metrics import accuracy_score 
accuracy_score(y_test, y_predict1)
# Out:
# 0.5622208040842374

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
y_predict2 = knn.predict(X_test)

# %%
knn.score(X_train, y_train)
# Out:
# 0.7217877094972067

# %%
knn.score(X_test, y_test)
# Out:
# 0.5768985322271857

# %%
accuracy_score(y_test, y_predict2)
# Out:
# 0.5768985322271857

# %%
from sklearn.tree import DecisionTreeClassifier
dt = DecisionTreeClassifier()
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_predict3 = dt.predict(X_test)

# %%
accuracy_score(y_test, y_predict3)
# Out:
# 0.5398851308232291

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict4 = rf.predict(X_test)

# %%
accuracy_score(y_test, y_predict4)
# Out:
# 0.5826419910657307

# %%
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_predict5 = xgb.predict(X_test)

# %%
accuracy_score(y_test, y_predict5)
# Out:
# 0.5768985322271857
