# %% [markdown]
# <a href="https://colab.research.google.com/github/anuragpatil811/Machine-Learning/blob/main/DataScaling_Normalization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
data = np.array([[100], [200], [300], [400], [500]])

# %%
scaler = MinMaxScaler()

# %%
new_data = scaler.fit_transform(data)
new_data
# Out:
# array([[0.  ],
#        [0.25],
#        [0.5 ],
#        [0.75],
#        [1.  ]])

# %%
from sklearn.preprocessing import StandardScaler
data1 = np.array([[1], [2], [3], [4], [5]])
scaler1 = StandardScaler()
standardized = scaler1.fit_transform(data1)
standardized
# Out:
# array([[-1.41421356],
#        [-0.70710678],
#        [ 0.        ],
#        [ 0.70710678],
#        [ 1.41421356]])
