# %%
import pandas as pd

# %%
df = pd.read_excel(r"C:\Users\Admin\Documents\Machine Learning\DBSCAN.xlsx")
df.head(3)
# Out:
#   Point  X  Y        P1   P2        P3        P4        P5         P6  \
# 0    P1  1  2  0.000000  1.0  1.414214  8.602325  9.219544  81.608823
# 1    P2  2  2  1.000000  0.0  1.000000  7.810250  8.485281  81.320354
# 2    P3  2  3  1.414214  1.0  0.000000  7.211103  7.810250  80.361682
#
#          P7        P8        P9       P10
# 0  5.477226  1.000000  9.899495  8.485281
# 1  5.477226  1.414214  9.219544  7.810250
# 2  4.472136  1.000000  8.485281  7.071068

# %%
df.drop(columns=["Point", "P1", "P2", "P3", "P4", "P5", "P6", "P7", "P8", "P9", "P10"], inplace=True)

# %%
df.head(3)
# Out:
#    X  Y
# 0  1  2
# 1  2  2
# 2  2  3

# %%
x = df[["X", "Y"]]

# %%
from sklearn.cluster import DBSCAN 
model = DBSCAN(eps=3, min_samples=3)
model.fit(x)
# Out:
# DBSCAN(eps=3, min_samples=3)

# %%
df["Output"] = model.fit_predict(x)

# %%
model.labels_
# Out:
# array([ 0,  0,  0,  1,  1, -1,  1,  0,  1,  1])

# %%
df0 = df[df["Output"]==0]
df1 = df[df["Output"]==1]
df2 = df[df["Output"]==-1]

# %%
import matplotlib.pyplot as plt 
plt.scatter(df0["X"], df0["Y"])
plt.scatter(df1["X"], df1["Y"])
plt.scatter(df2["X"], df2["Y"])
