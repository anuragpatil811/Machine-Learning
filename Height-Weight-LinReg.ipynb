# %%
import pandas as pd 
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
data = {
    'weight in lbs': [140, 155, 159, 179, 192, 200, 212],
    'height in inches': [60, 62, 67, 70, 71, 72, 75]
}

# %%
df = pd.DataFrame(data)

# %%
x = df.drop('height in inches', axis=1)
y = df['height in inches']

# %%
model = LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x)
y_pred
# Out:
# array([60.7964693 , 63.7979118 , 64.59829647, 68.60021981, 71.20146998,
#        72.80223932, 75.20339332])

# %%
r2_score(y, y_pred)
# Out:
# 0.9311184259327128

# %%
import matplotlib.pyplot as plt 
plt.scatter(x, y, label="Actual Values")
plt.plot(x, y_pred, label="Predicted Values")
