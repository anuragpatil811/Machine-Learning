# %%
d = {"x": [1, 2, 3, 4], 
     "y": [40, 50, 65, 70]}

# %%
import pandas as pd

# %%
df = pd.DataFrame(d)

# %%
df.isnull().sum()
# Out:
# x    0
# y    0
# dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["x"], df["y"], label="actual value")

# %%
x = df[["x"]]

# %%
y = df["y"]

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(x, y)
# Out:
# LinearRegression()

# %%
model.coef_
# Out:
# array([10.5])

# %%
model.intercept_
# Out:
# np.float64(30.0)

# %%
y_predict = model.predict(x)
y_predict
# Out:
# array([40.5, 51. , 61.5, 72. ])

# %%
model.predict([[2.5]])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([56.25])

# %%
plt.scatter(df["x"], df["y"], label="actual value")
plt.plot(df["x"], y_predict, label="predicted value")
plt.legend()

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y, y_predict)
# Out:
# 1.75

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y, y_predict)
# Out:
# 4.375

# %%
from sklearn.metrics import r2_score
r2_score(y, y_predict)
# Out:
# 0.9692307692307692
