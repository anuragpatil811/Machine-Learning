# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\DELL\OneDrive\Documents\Machine Learning\Spotify Dataset.csv", sep=";")
df.head(3)
# Out:
#    Rank            Title                     Artists        Date  \
# 0     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 1     1  Ella Baila Sola  Eslabon Armado, Peso Pluma  29/05/2023
# 2     2   WHERE SHE GOES                   Bad Bunny  29/05/2023
#
#    Danceability  Energy  Loudness  Speechiness  Acousticness  \
# 0         0.668   0.758   -5176.0        0.033         0.483
# 1         0.668   0.758   -5176.0        0.033         0.483
# 2         0.652   0.800   -4019.0        0.061         0.143
#
#    Instrumentalness  Valence # of Artist   Artist (Ind.) # of Nationality  \
# 0             0.000    0.834    Artist 1  Eslabon Armado    Nationality 1
# 1             0.000    0.834    Artist 2      Peso Pluma    Nationality 2
# 2             0.629    0.234    Artist 1       Bad Bunny    Nationality 1
#
#    Nationality      Continent  Points (Total)  \
# 0       Mexico  Latin-America             200
# 1       Mexico  Latin-America             200
# ...

# %%
df.isnull().sum()
# Out:
# Rank                                0
# Title                               0
# Artists                             0
# Date                                0
# Danceability                        0
# Energy                              0
# Loudness                            0
# Speechiness                         0
# Acousticness                        0
# Instrumentalness                    0
# Valence                             0
# # of Artist                         0
# Artist (Ind.)                       0
# # of Nationality                    0
# Nationality                         0
# Continent                           0
# Points (Total)                      0
# Points (Ind for each Artist/Nat)    0
# id                                  0
# Song URL                            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop(columns=['Artists', 'Date'], inplace=True)

# %%
df.dtypes
# Out:
# Rank                                  int64
# Title                                   str
# Danceability                        float64
# Energy                              float64
# Loudness                            float64
# Speechiness                         float64
# Acousticness                        float64
# Instrumentalness                    float64
# Valence                             float64
# # of Artist                             str
# Artist (Ind.)                           str
# # of Nationality                        str
# Nationality                             str
# Continent                               str
# Points (Total)                        int64
# Points (Ind for each Artist/Nat)    float64
# id                                      str
# Song URL                                str
# dtype: object

# %%
df.drop(columns=['# of Nationality', 'id'], inplace=True)

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Valence', '# of Artist',
#        'Artist (Ind.)', 'Nationality', 'Continent', 'Points (Total)',
#        'Points (Ind for each Artist/Nat)', 'Song URL'],
#       dtype='str')

# %%
df.drop(columns=['# of Artist', 'Continent'], inplace=True)

# %%
import seaborn as sns
sns.boxplot(data=df, y="Danceability")
# Out:
# <Axes: ylabel='Danceability'>

# %%
df["Danceability"].describe()
# Out:
# count    651936.000000
# mean          0.697730
# std           0.133186
# min           0.073000
# 25%           0.617000
# 50%           0.719000
# 75%           0.793000
# max           0.985000
# Name: Danceability, dtype: float64

# %%
q1=0.617
q3=0.793
IQR = q3-q1

# %%
ub = q3+1.5*IQR
lb = q1 - 1.5*IQR

# %%
df = df[(df["Danceability"]>lb)&(df["Danceability"]<ub)]

# %%
sns.boxplot(data=df, y="Danceability")
# Out:
# <Axes: ylabel='Danceability'>

# %%
sns.boxplot(data=df, y="Energy")
# Out:
# <Axes: ylabel='Energy'>

# %%
df["Energy"].describe()
# Out:
# count    639623.000000
# mean          0.655336
# std           0.152094
# min           0.005000
# 25%           0.555000
# 50%           0.672000
# 75%           0.771000
# max           0.996000
# Name: Energy, dtype: float64

# %%
q1 = 0.555
q3 = 0.771
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR
lb = q1 - 1.5*IQR 
df = df[(df["Energy"]>lb)&(df["Energy"]<ub)]

# %%
sns.boxplot(data=df, y="Energy")
# Out:
# <Axes: ylabel='Energy'>

# %%
sns.boxplot(data=df, y="Loudness")
# Out:
# <Axes: ylabel='Loudness'>

# %%
df["Loudness"].describe()
# Out:
# count    635226.000000
# mean      -5184.018185
# std        2624.264606
# min      -19697.000000
# 25%       -6725.000000
# 50%       -5144.000000
# 75%       -3838.000000
# max        1509.000000
# Name: Loudness, dtype: float64

# %%
q1 = -6725.0
q3 = -3838.0
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR
lb = q1 - 1.5*IQR
df = df[(df["Loudness"]>lb)&(df["Loudness"]<ub)]

# %%
sns.boxplot(data=df, y="Loudness")
# Out:
# <Axes: ylabel='Loudness'>

# %%
sns.boxplot(data=df, y="Speechiness")
# Out:
# <Axes: ylabel='Speechiness'>

# %%
df["Speechiness"].describe()
# Out:
# count    625319.000000
# mean          0.110726
# std           0.096250
# min           0.022000
# 25%           0.045000
# 50%           0.070000
# 75%           0.138000
# max           0.920000
# Name: Speechiness, dtype: float64

# %%
q1 = 0.045
q3 = 0.138
IQR = q3 - q1

# %%
ub = q3+1.5*IQR
lb = q1 - 1.5*IQR

# %%
df = df[(df["Speechiness"]>lb)&(df["Speechiness"]<ub)]
sns.boxplot(data=df, y="Speechiness")
# Out:
# <Axes: ylabel='Speechiness'>

# %%
sns.boxplot(data=df, y="Acousticness")
# Out:
# <Axes: ylabel='Acousticness'>

# %%
df["Acousticness"].describe()
# Out:
# count    569885.000000
# mean          0.214923
# std           0.214847
# min           0.000000
# 25%           0.044000
# 50%           0.142000
# 75%           0.325000
# max           0.992000
# Name: Acousticness, dtype: float64

# %%
q1 = 0.044
q3 = 0.325
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR
lb = q1 - 1.5*IQR 
df = df[(df["Acousticness"]>lb)&(df["Acousticness"]<ub)]

# %%
sns.boxplot(data=df, y="Acousticness")
# Out:
# <Axes: ylabel='Acousticness'>

# %%
sns.boxplot(data=df, y="Instrumentalness")
# Out:
# <Axes: ylabel='Instrumentalness'>

# %%
df["Points (Total)"].describe()
# Out:
# count    551329.000000
# mean        101.288826
# std          57.603587
# min           1.000000
# 25%          51.000000
# 50%         102.000000
# 75%         151.000000
# max         200.000000
# Name: Points (Total), dtype: float64

# %%
sns.boxplot(data=df, y="Points (Total)")
# Out:
# <Axes: ylabel='Points (Total)'>

# %%
sns.boxplot(data=df, y="Points (Ind for each Artist/Nat)")
# Out:
# <Axes: ylabel='Points (Ind for each Artist/Nat)'>

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Danceability', 'Energy', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Valence', 'Artist (Ind.)',
#        'Nationality', 'Points (Total)', 'Points (Ind for each Artist/Nat)',
#        'Song URL'],
#       dtype='str')

# %%
X = df[['Danceability', 'Energy', 'Loudness', 'Speechiness',
       'Acousticness', 'Instrumentalness', 'Valence']]

# %%
X.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 551329 entries, 0 to 651935
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Danceability      551329 non-null  float64
#  1   Energy            551329 non-null  float64
#  2   Loudness          551329 non-null  float64
#  3   Speechiness       551329 non-null  float64
#  4   Acousticness      551329 non-null  float64
#  5   Instrumentalness  551329 non-null  float64
#  6   Valence           551329 non-null  float64
# dtypes: float64(7)
# memory usage: 33.7 MB

# %%
X.describe()
# Out:
#         Danceability         Energy       Loudness    Speechiness  \
# count  551329.000000  551329.000000  551329.000000  551329.000000
# mean        0.709579       0.675228   -4953.877448       0.088010
# std         0.119681       0.135855    2352.875014       0.061114
# min         0.353000       0.234000  -11052.000000       0.022000
# 25%         0.635000       0.575000   -6442.000000       0.044000
# 50%         0.728000       0.688000   -5025.000000       0.063000
# 75%         0.795000       0.782000   -3758.000000       0.112000
# max         0.985000       0.996000       0.963000       0.277000
#
#         Acousticness  Instrumentalness        Valence
# count  551329.000000     551329.000000  551329.000000
# mean        0.194393          0.005628       0.537976
# std         0.186084          0.044850       0.220362
# min         0.000000          0.000000       0.035000
# 25%         0.041000          0.000000       0.374000
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X = sc.fit_transform(X)

# %%
from sklearn.cluster import KMeans
km = KMeans(n_clusters=3)
km.fit(X)
# Out:
# KMeans(n_clusters=3)

# %%
km.fit_transform(X)
# Out:
# array([[11.03285551,  2.95654452,  2.33651884],
#        [11.03285551,  2.95654452,  2.33651884],
#        [ 4.05184815, 14.13895175, 14.13840864],
#        ...,
#        [10.81739425,  2.69726279,  1.53997369],
#        [11.178709  ,  4.03415601,  2.94202915],
#        [11.178709  ,  4.03415601,  2.94202915]], shape=(551329, 3))

# %%
km.predict(X)
# Out:
# array([2, 2, 0, ..., 2, 2, 2], shape=(551329,), dtype=int32)
