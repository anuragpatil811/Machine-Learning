# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\Admin\Documents\Machine Learning\customers.csv')
df.head()
# Out:
#    Channel  Region  Fresh  Milk  Grocery  Frozen  Detergents_Paper  \
# 0        2       3  12669  9656     7561     214              2674
# 1        2       3   7057  9810     9568    1762              3293
# 2        2       3   6353  8808     7684    2405              3516
# 3        1       3  13265  1196     4221    6404               507
# 4        2       3  22615  5410     7198    3915              1777
#
#    Delicatessen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185

# %%
df.isnull().sum()
# Out:
# Channel             0
# Region              0
# Fresh               0
# Milk                0
# Grocery             0
# Frozen              0
# Detergents_Paper    0
# Delicatessen        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import seaborn as sns 
sns.boxplot(data=df, y='Delicatessen')
# Out:
# <Axes: ylabel='Delicatessen'>

# %%
df["Fresh"].describe()
# Out:
# count       440.000000
# mean      12000.297727
# std       12647.328865
# min           3.000000
# 25%        3127.750000
# 50%        8504.000000
# 75%       16933.750000
# max      112151.000000
# Name: Fresh, dtype: float64

# %%
q1 = 3127.75
q3 = 16933.75
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["Fresh"]>lb)&(df["Fresh"]<ub)]

# %%
sns.boxplot(data=df, y="Fresh")
# Out:
# <Axes: ylabel='Fresh'>

# %%
df["Milk"].describe()
# Out:
# count      420.000000
# mean      5738.319048
# std       7047.239079
# min         55.000000
# 25%       1533.000000
# 50%       3627.000000
# 75%       7277.500000
# max      73498.000000
# Name: Milk, dtype: float64

# %%
q1 = 1533.0
q3 = 7277.5
IQR = q3 - q1
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["Milk"]>lb)&(df["Milk"]<ub)]

# %%
sns.boxplot(data=df, y="Milk")
# Out:
# <Axes: ylabel='Milk'>

# %%
df["Grocery"].describe()
# Out:
# count      396.000000
# mean      6789.361111
# std       6913.890902
# min          3.000000
# 25%       2099.250000
# 50%       4496.000000
# 75%       9631.000000
# max      67298.000000
# Name: Grocery, dtype: float64

# %%
q1 = 2099.25
q3 = 9631.00
IQR = q3 - q1 
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["Grocery"]>lb)&(df["Grocery"]<ub)]

# %%
df["Frozen"].describe()
# Out:
# count      377.000000
# mean      2714.856764
# std       3536.905294
# min         25.000000
# 25%        666.000000
# 50%       1455.000000
# 75%       3242.000000
# max      35009.000000
# Name: Frozen, dtype: float64

# %%
q1 = 666.00
q3 = 3242.00
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR 
df = df[(df["Frozen"]>lb)&(df["Frozen"]<ub)]

# %%
sns.boxplot(data=df, y="Frozen")
# Out:
# <Axes: ylabel='Frozen'>

# %%
df.describe()
# Out:
#           Channel      Region          Fresh          Milk       Grocery  \
# count  440.000000  440.000000     440.000000    440.000000    440.000000
# mean     1.322727    2.543182   12000.297727   5796.265909   7951.277273
# std      0.468052    0.774272   12647.328865   7380.377175   9503.162829
# min      1.000000    1.000000       3.000000     55.000000      3.000000
# 25%      1.000000    2.000000    3127.750000   1533.000000   2153.000000
# 50%      1.000000    3.000000    8504.000000   3627.000000   4755.500000
# 75%      2.000000    3.000000   16933.750000   7190.250000  10655.750000
# max      2.000000    3.000000  112151.000000  73498.000000  92780.000000
#
#              Frozen  Detergents_Paper  Delicatessen
# count    440.000000        440.000000    440.000000
# mean    3071.931818       2881.493182   1524.870455
# std     4854.673333       4767.854448   2820.105937
# min       25.000000          3.000000      3.000000
# ...

# %%
df["Detergents_Paper"].describe()
# Out:
# count      340.000000
# mean      2098.970588
# std       2657.015235
# min          3.000000
# 25%        238.750000
# 50%        770.500000
# 75%       3521.250000
# max      17120.000000
# Name: Detergents_Paper, dtype: float64

# %%
q1 = 238.75
q3 = 3521.25
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["Detergents_Paper"]>lb)&(df["Detergents_Paper"]<ub)]

# %%
sns.boxplot(data=df, y="Detergents_Paper")
# Out:
# <Axes: ylabel='Detergents_Paper'>

# %%
df["Delicatessen"].describe()
# Out:
# count     331.000000
# mean     1145.661631
# std      1138.068670
# min         3.000000
# 25%       376.500000
# 50%       778.000000
# 75%      1546.000000
# max      7844.000000
# Name: Delicatessen, dtype: float64

# %%
q1 = 376.5
q3 = 1546.0
IQR = q3 - q1

# %%
ub = q3 + 1.5*IQR 
lb = q1 - 1.5*IQR

# %%
df = df[(df["Delicatessen"]>lb)&(df["Delicatessen"]<ub)]

# %%
sns.boxplot(data=df, y="Delicatessen")
# Out:
# <Axes: ylabel='Delicatessen'>

# %%
df.describe()
# Out:
#           Channel      Region         Fresh          Milk       Grocery  \
# count  318.000000  318.000000  3.180000e+02    318.000000    318.000000
# mean     1.270440    2.559748  7.541138e-17   3989.176101   5563.682390
# std      0.444887    0.770851  1.001576e+00   3260.597084   4623.066729
# min      1.000000    1.000000 -1.186627e+00     55.000000      3.000000
# 25%      1.000000    2.000000 -8.151940e-01   1329.500000   2001.500000
# 50%      1.000000    3.000000 -2.341049e-01   3045.000000   3815.500000
# 75%      2.000000    3.000000  5.333419e-01   6188.000000   8435.500000
# max      2.000000    3.000000  3.336647e+00  15729.000000  20292.000000
#
#             Frozen  Detergents_Paper  Delicatessen
# count   318.000000        318.000000    318.000000
# mean   1799.654088       1840.603774    984.191824
# std    1612.664020       2206.607239    785.423600
# min      25.000000          3.000000      3.000000
# 25%     575.250000        228.750000    360.250000
# ...

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
df["Fresh"] = scaler.fit_transform(df[["Fresh"]])

# %%
df["Milk"] = scaler.fit_transform(df[["Milk"]])

# %%
df["Grocery"] = scaler.fit_transform(df[["Frozen"]])

# %%
df["Frozen"] = scaler.fit_transform(df[["Fresh"]])

# %%
df["Detergents_Paper"] = scaler.fit_transform(df[["Detergents_Paper"]])

# %%
df["Delicatessen"] = scaler.fit_transform(df[["Delicatessen"]])

# %%
df.describe()
# Out:
#           Channel      Region         Fresh          Milk       Grocery  \
# count  318.000000  318.000000  3.180000e+02  3.180000e+02  3.180000e+02
# mean     1.270440    2.559748  7.541138e-17  4.468822e-17  5.586028e-17
# std      0.444887    0.770851  1.001576e+00  1.001576e+00  1.001576e+00
# min      1.000000    1.000000 -1.186627e+00 -1.208483e+00 -1.102183e+00
# 25%      1.000000    2.000000 -8.151940e-01 -8.169877e-01 -7.604397e-01
# 50%      1.000000    3.000000 -2.341049e-01 -2.900279e-01 -3.758426e-01
# 75%      2.000000    3.000000  5.333419e-01  6.754252e-01  4.719169e-01
# max      2.000000    3.000000  3.336647e+00  3.606188e+00  3.133509e+00
#
#              Frozen  Detergents_Paper  Delicatessen
# count  3.180000e+02      3.180000e+02  3.180000e+02
# mean   1.815459e-17     -1.117206e-17 -7.820439e-17
# std    1.001576e+00      1.001576e+00  1.001576e+00
# min   -1.186627e+00     -8.340859e-01 -1.251221e+00
# 25%   -8.151940e-01     -7.316183e-01 -7.956537e-01
# ...
