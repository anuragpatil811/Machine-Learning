# %%
import pandas as pd

# %%
l = [1, 2, 3, 4, 5, 6, 7]
out = [0, 1, 0, 1, 0, 1, 1]

# %%
from sklearn.model_selection import KFold

# %%
kf = KFold(n_splits=3)

# %%
kf.split(l)
# Out:
# <generator object _BaseKFold.split at 0x0000024B82E916C0>

# %%
for X_train, X_test in kf.split(l):
    print(X_train, X_test)
# Out:
# [3 4 5 6] [0 1 2]
# [0 1 2 5 6] [3 4]
# [0 1 2 3 4] [5 6]
